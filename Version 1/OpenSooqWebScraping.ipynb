# %% [markdown]
# # `Open Sooq` Web Scraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0"}

# %%
base_url = "https://om.opensooq.com/en/property/property-for-rent"
current_page_url = rent_url

# %%
property_data = {
                "propert_title": [], 
                "propert_location": [], 
                "price": [], 
                "area": [], 
                "listing_type": []
}

# %%
page_number = 1
while True:
    print(f"scarpping page {page_number}...")
    try:
        response = requests.get(current_page_url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"error fetching page {current_page_url}: {e}")
        break

    soup = BeautifulSoup(response.content, "html.parser")
    properties = soup.find_all('div', class_="postDet flex flex-1 flexWrap flexSpaceBetween flexDirectionColumn overflowHidden ripple")
    if not properties:
        print("No Property Found!")
        break
    for card in properties:
        title = card.find("div", class_="flex flexSpaceBetween gap-10")
        property_data["propert_title"].append(title.text.strip() if title else None)

        location = card.find("div", class_="flex alignItems gap-5 darkGrayColor")
        property_data["propert_location"].append(location.text.strip() if location else None)   

        price = card.find("div", class_="priceColor bold alignSelfCenter font-18 ms-auto")
        property_data["price"].append(price.text.strip() if price else None)
        
        size = None
        p_tag = card.find("p")
        if p_tag and p_tag.text:
            match = re.search(r"Surface\s*Area:\s*([\d,]+)\s*m2", p_tag.text, re.IGNORECASE)
            if match:
                size = match.group(1).replace(",", "")
        property_data["area"].append(size)

        property_data["listing_type"].append("For Rent")
        
    next_button = soup.find('a', class_='blueHoverBg border pagerItem flex alignItems justifyContent radius-8 ripple', attrs={'title':"Go to next page"}, href=True)
    if next_button:
        next_page_relative_url = next_button["href"]
        new_url = requests.compat.urljoin(base_url, next_page_relative_url)

    if new_url == current_page_url:
        print("Reached the last page. No more properties found!")
        break
    else:
        current_page_url = new_url
        page_number += 1
        time.sleep(1)
# Out:
# scarpping page 1...
# scarpping page 2...
# scarpping page 3...
# scarpping page 4...
# scarpping page 5...
# scarpping page 6...
# scarpping page 7...
# scarpping page 8...
# scarpping page 9...
# scarpping page 10...
# scarpping page 11...
# scarpping page 12...
# scarpping page 13...
# scarpping page 14...
# scarpping page 15...
# scarpping page 16...
# scarpping page 17...
# scarpping page 18...
# scarpping page 19...
# scarpping page 20...
# scarpping page 21...
# scarpping page 22...
# scarpping page 23...
# scarpping page 24...
# scarpping page 25...
# scarpping page 26...
# scarpping page 27...
# scarpping page 28...
# scarpping page 29...
# scarpping page 30...
# scarpping page 31...
# scarpping page 32...
# scarpping page 33...
# scarpping page 34...
# scarpping page 35...
# scarpping page 36...
# scarpping page 37...
# scarpping page 38...
# scarpping page 39...
# scarpping page 40...
# scarpping page 41...
# scarpping page 42...
# scarpping page 43...
# scarpping page 44...
# scarpping page 45...
# scarpping page 46...
# scarpping page 47...
# scarpping page 48...
# scarpping page 49...
# scarpping page 50...
# scarpping page 51...
# scarpping page 52...
# scarpping page 53...
# scarpping page 54...
# scarpping page 55...
# scarpping page 56...
# scarpping page 57...
# scarpping page 58...
# scarpping page 59...
# scarpping page 60...
# scarpping page 61...
# scarpping page 62...
# scarpping page 63...
# scarpping page 64...
# scarpping page 65...
# scarpping page 66...
# scarpping page 67...
# scarpping page 68...
# scarpping page 69...
# scarpping page 70...
# scarpping page 71...
# scarpping page 72...
# scarpping page 73...
# scarpping page 74...
# scarpping page 75...
# scarpping page 76...
# scarpping page 77...
# scarpping page 78...
# scarpping page 79...
# scarpping page 80...
# scarpping page 81...
# scarpping page 82...
# scarpping page 83...
# scarpping page 84...
# scarpping page 85...
# scarpping page 86...
# scarpping page 87...
# scarpping page 88...
# scarpping page 89...
# scarpping page 90...
# scarpping page 91...
# scarpping page 92...
# scarpping page 93...
# scarpping page 94...
# scarpping page 95...
# scarpping page 96...
# scarpping page 97...
# scarpping page 98...
# scarpping page 99...
# scarpping page 100...
# scarpping page 101...
# scarpping page 102...
# scarpping page 103...
# scarpping page 104...
# scarpping page 105...
# scarpping page 106...
# scarpping page 107...
# scarpping page 108...
# scarpping page 109...
# scarpping page 110...
# scarpping page 111...
# scarpping page 112...
# scarpping page 113...
# scarpping page 114...
# scarpping page 115...
# scarpping page 116...
# scarpping page 117...
# scarpping page 118...
# scarpping page 119...
# scarpping page 120...
# scarpping page 121...
# scarpping page 122...
# scarpping page 123...
# scarpping page 124...
# scarpping page 125...
# scarpping page 126...
# scarpping page 127...
# scarpping page 128...
# scarpping page 129...
# scarpping page 130...
# scarpping page 131...
# scarpping page 132...
# scarpping page 133...
# scarpping page 134...
# scarpping page 135...
# scarpping page 136...
# scarpping page 137...
# scarpping page 138...
# scarpping page 139...
# scarpping page 140...
# scarpping page 141...
# scarpping page 142...
# scarpping page 143...
# scarpping page 144...
# scarpping page 145...
# scarpping page 146...
# scarpping page 147...
# scarpping page 148...
# scarpping page 149...
# scarpping page 150...
# scarpping page 151...
# scarpping page 152...
# scarpping page 153...
# scarpping page 154...
# scarpping page 155...
# scarpping page 156...
# scarpping page 157...
# scarpping page 158...
# scarpping page 159...
# scarpping page 160...
# scarpping page 161...
# scarpping page 162...
# scarpping page 163...
# scarpping page 164...
# scarpping page 165...
# scarpping page 166...
# scarpping page 167...
# scarpping page 168...
# scarpping page 169...
# scarpping page 170...
# scarpping page 171...
# scarpping page 172...
# scarpping page 173...
# scarpping page 174...
# scarpping page 175...
# scarpping page 176...
# scarpping page 177...
# scarpping page 178...
# scarpping page 179...
# Reached the last page. No more properties found!

# %%
df = pd.DataFrame(property_data)
df
# Out:
#                                           propert_title  \
# 0     120000 m2 3 Bedrooms Apartments for Rent in Dh...
# 1           3 Bedrooms Chalet for Rent in Dhofar Salala
# 2     10 m2 Studio Apartments for Rent in Muscat Amerat
# 3                  Furnished Daily in Muscat Al Mawaleh
# 4     للإيجار مكتب  تجاري واجهة على شارع مزون - معرض...
# ...                                                 ...
# 5455  For Rent: Office Spaces from 70–240 SQM  Prime...
# 5456         قوس ورد للمدخل للإيجار shop entrance decor
# 5457                                    جهاز حمام مغربي
# 5458  300 m2 4 Bedrooms Townhouse for Rent in Muscat...
# 5459                               للبيع فرن صبغ مركبات
#
#            propert_location    price    area listing_type
# 0            Dhofar, Salala   35 OMR  120000     For Rent
# 1            Dhofar, Salala              250     For Rent
# 2            Muscat, Amerat    7 OMR      10     For Rent
# 3        Muscat, Al Mawaleh    8 OMR    None     For Rent
# 4          Muscat, Al Khoud  600 OMR     125     For Rent
# ...                     ...      ...     ...          ...
# 5455        Muscat, Hamriya  275 OMR      70     For Rent
# 5456           Muscat, Ruwi   50 OMR    None     For Rent
# 5457           Muscat, Ruwi  120 OMR    None     For Rent
# 5458           Muscat, Qurm  450 OMR     300     For Rent
# 5459  Muscat, Wadi Al Kabir    3 OMR    None     For Rent
#
# [5460 rows x 5 columns]

# %%
df.to_csv("OpenSooq.csv", index=False)
